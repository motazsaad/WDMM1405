# %%
class Number:
    def __init__(self, v=0):
        self.v = v 
    def __str__(self):
        return str(self.v)
    def __add__(self, x):
        self.v += x

# %%
n = Number(3)
print(n)
# Out:
# 3

# %%
n + 3

# %%
print(n)
# Out:
# 6

# %%
type(n)
# Out:
# __main__.Number

# %%
x = 3 # primitive int

# %%
x += 3

# %%
print(x)
# Out:
# 6

# %%
type(x)
# Out:
# int
