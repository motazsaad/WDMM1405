# %% [markdown]
# # Chapter 7 Reading files in Python

# %%
file_handle = open('Ahmed_file.txt', 'r')

# %%
file_handle
# Out:
# <_io.TextIOWrapper name='Ahmed_file.txt' mode='r' encoding='UTF-8'>

# %%
file_handle = open('myfile.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-080b0e91cc46> in <module>
# ----> 1 file_handle = open('myfile.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
text = 'hi\nthere'

# %%
text
# Out:
# 'hi\nthere'

# %%
print(text)
# Out:
# hi
# there

# %%
len('x\ny')
# Out:
# 3

# %%
len('x\ty')
# Out:
# 3

# %%
print('x\ty')
# Out:
# x	y

# %% [markdown]
# # two ways to read files
#
# 1. read line line by line
# 2. read the whole file

# %% [markdown]
# # read file line by line

# %%
file_handle = open('Ahmed_file.txt', 'r')
for line in file_handle:
    print(line)
# Out:
# Hello my name is 	Ahmed
#
# I like python
#
# Python is cool

# %%
print('hello')
# Out:
# hello

# %%
print('hello\n')
# Out:
# hello

# %%
file_handle = open('Ahmed_file.txt', 'r')
for line in file_handle:
    print(line.strip())
# Out:
# Hello my name is 	Ahmed
# I like python
# Python is cool

# %% [markdown]
# # اكتب برنامج لعد عدد الاسطر في ملف معين

# %%
fhandle = open('Ahmed_file.txt') # default mode is read 
# fhandle = open('Ahmed_file.txt', 'r') 
count = 0 
for line in fhandle:
    count += 1 
count
# Out:
# 3

# %% [markdown]
# # open file in different path

# %% [markdown]
# ## relative path مسار نسبي

# %%
fhandle = open('files/file101.txt')
for line in fhandle:
    print(line.strip())
# Out:
# Hello world
# hello again
# مرحبا

# %% [markdown]
# ## full path مسار كامل

# %%
fhandle = open('/home/motaz/Desktop/testfile.txt')
for line in fhandle:
    print(line.strip())
# Out:
# hello, this file is on desktop

# %% [markdown]
# # file path in Windows

# %%
print('dir1\file1.txt')
# Out:
# dir1ile1.txt

# %%
print('dir1\\file1.txt')
# Out:
# dir1\file1.txt

# %%
print('c:\users\msaad\Dektop\file.txt')
# Out:
#   File "<ipython-input-10-8e0f5b4d964b>", line 1
#     print('c:\users\msaad\Dektop\file.txt')
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape

# %%
print('c:\\users\\msaad\\Dektop\\file.txt')
# Out:
# c:\users\msaad\Dektop\file.txt

# %%
print('c:/users/msaad/Dektop/file.txt')
# Out:
# c:/users/msaad/Dektop/file.txt

# %% [markdown]
# # Encoding

# %%
fhandle = open('files/file101.txt')
print(fhandle)
for line in fhandle:
    print(line.strip())
# Out:
# <_io.TextIOWrapper name='files/file101.txt' mode='r' encoding='UTF-8'>
# Hello world
# hello again
# مرحبا

# %%
fhandle = open('files/file101.txt', encoding='cp1256')
print(fhandle)
for line in fhandle:
    print(line.strip())
# Out:
# <_io.TextIOWrapper name='files/file101.txt' mode='r' encoding='cp1256'>
# Hello world
# hello again
# ظ…ط±ط­ط¨ط§

# %%
fhandle = open('files/file101.txt', encoding='utf-8')
print(fhandle)
for line in fhandle:
    print(line.strip())
# Out:
# <_io.TextIOWrapper name='files/file101.txt' mode='r' encoding='utf-8'>
# Hello world
# hello again
# مرحبا

# %% [markdown]
# # اكتب برنامج لعد عدد الاسطر في ملف معين

# %%
fh = open('files/mbox-short.txt')
count = 0 
for line in fh:
    count += 1
count
# Out:
# 1910

# %%
fh = open('files/mbox.txt')
count = 0 
for line in fh:
    count += 1
count
# Out:
# 132045

# %% [markdown]
# # Method 2: readling the whole file

# %%
file_handle = open('../files/mbox-short.txt')
text = file_handle.read()

# %%
text[:100]
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiprojec'

# %%
print(text[:100])
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiprojec

# %%
len(text[:100])
# Out:
# 100

# %%
text[3:7]
# number of chars: 7-3 = 4 letters 
# index: 3, 4, 5, 6
# letters: 4, 5, 6, 7
# Out:
# 'm st'

# %% [markdown]
# # كم عدد الاحرف في الملف

# %%
len(text)
# Out:
# 94626

# %% [markdown]
# # كم عدد الكلمات في الملف

# %%
len(text.split())
# Out:
# 8272

# %% [markdown]
# # عدد الاسطر في الملف

# %%
text.count('\n')
# Out:
# 1910

# %%
len(text.split('\n'))
# Out:
# 1911

# %%
lines = text.split('\n')

# %%
lines[:5]
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'Return-Path: <postmaster@collab.sakaiproject.org>',
#  'Received: from murder (mail.umich.edu [141.211.14.90])',
#  '\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;',
#  '\t Sat, 05 Jan 2008 09:14:16 -0500']

# %%
file_handle = open('../files/mbox.txt')
text = file_handle.read()

# %%
# number of chars 
len(text)
# Out:
# 6687002

# %%
# number of words 
len(text.split())
# Out:
# 547789

# %%
# number of lines 
len(text.split('\n'))
# Out:
# 132046

# %% [markdown]
# # اكتب برنامج لعد عدد الرسائل البريد الالكتروني من الملف

# %%
# method 1: read file line by line 
file_handle = open('../files/mbox.txt')
count = 0 
for line in file_handle:
    if line.startswith('From:'):
        count += 1 
count
# Out:
# 1797

# %%
# method 2: read the whole file 
file_handle = open('../files/mbox.txt')
text = file_handle.read()

# %%
lines  = text.split('\n')

# %%
count = 0 
for line in lines:
    if line.startswith('From:'):
        count += 1 
count
# Out:
# 1797

# %% [markdown]
# # compare reading methods: line by line vs whole file
#
# * reading files line by line, you need disk read operation for every line, so it is slow, but it is useful for large files
# * reading the whole file is faster than "line by line", but you can not use it for large files.

# %% [markdown]
# # اكتب برنامج للبحث عن عناوين البريد الالكتروني وطباعتها من الملف

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:'):
        print(line.strip())
        count += 1 
count
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# 27

# %% [markdown]
# # اطبع فقط البريد الالكتروني في المسألة السابقة

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:'):
        print(line.strip().replace('From: ', ''))
        count += 1 
count
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# 27

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:'):
        words = line.split()
        print(words[1])
        count += 1 
count
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# 27

# %% [markdown]
# # من السؤال السابق ، اطبع عناوين البريد الالكتروني من هذا النطاق فقط
# domain: @uct.ac.za

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:') and line.endswith('@uct.ac.za'):
        words = line.split()
        print(words[1])
        count += 1 
count
# Out:
# 0

# %%
'@uct.ac.za' == '@uct.ac.za\n'
# Out:
# False

# %%
'@uct.ac.za\n'.strip()
# Out:
# '@uct.ac.za'

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:') and line.strip().endswith('@uct.ac.za'):
        words = line.split()
        print(words[1])
        count += 1 
count
# Out:
# stephen.marquard@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# 6

# %%
# using continue 
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:'):
        if not '@uct.ac.za' in line:
            continue 
        words = line.split()
        print(words[1])
        count += 1 
count
# Out:
# stephen.marquard@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# 6

# %% [markdown]
# # اطبع كل الرسائل من بريطانيا

# %%
file_handle = open('../files/mbox-short.txt')
count = 0
for line in file_handle:
    if line.startswith('From:') and line.strip().endswith('.uk'):
        words = line.split()
        print(words[1])
        count += 1 
count
# Out:
# antranig@caret.cam.ac.uk
# 1

# %% [markdown]
# # اكتب كود يطلب من المستخدم ادخال اسم ملف وطباعة محتواه

# %%
file_name = input('enter file name:')
file_handle = open(file_name)
text = file_handle.read()
print(text)
# Out:
# enter file name: Ahmed_file.txt
# Hello my name is 	Ahmed
# I like python
# Python is cool

# %%
file_name = input('enter file name:')
file_handle = open(file_name)
text = file_handle.read()
print(text)
# Out:
# enter file name: file111.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-9d0531729790> in <module>
#       1 file_name = input('enter file name:')
# ----> 2 file_handle = open(file_name)
#       3 text = file_handle.read()
#       4 print(text)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file111.txt'

# %%
file_name = input('enter file name:')
try:
    file_handle = open(file_name)
    text = file_handle.read()
    print(text)
except FileNotFoundError:
    print('file not found')
# Out:
# enter file name: file1111.txt
# file not found

# %% [markdown]
# # Writing to files in python

# %%
file_handle = open('myfile02.txt', 'w')
file_handle.write('hello, python is cool')
file_handle.close()

# %%
file_handle = open('myfile02.txt', 'w') # over write 
file_handle.write('hello again')
file_handle.close()

# %% [markdown]
# #  من السؤال السابق ، خزن عناوين البريد الالكتروني من هذا النطاق فقط على ملف
#
# domain: @uct.ac.za

# %%
infile = open('../files/mbox-short.txt')
outfile = open('emails_uct.txt', 'w')
count = 0
for line in infile:
    if line.startswith('From:') and line.strip().endswith('@uct.ac.za'):
        words = line.split()
        outfile.write(words[1] + '\n')
        count += 1 

infile.close()
outfile.close()
count
# Out:
# 6

# %% [markdown]
# # اكتب برنامج لاستخراج كل عناوين البريد المرسلة في عام 2008

# %%
infile = open('../files/mbox.txt')
outfile = open('emails_2008.txt', mode='w')
lines = infile.read().split('\n')
for line in lines:
    if line.startswith('From ') and line.strip().endswith('2008'):
        outfile.write(line.split()[1] + '\n')
infile.close()
outfile.close()

# %% [markdown]
# # split vs strip

# %%
' hello my name is Ahmed\n'.strip()
# Out:
# 'hello my name is Ahmed'

# %%
' hello my name is Ahmed\n'.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Ahmed']

# %% [markdown]
# # اكتب برنامج لاستخراج عناوين البريد المرسل والمستقبل والسنة

# %%
infile = open('../files/mbox-short.txt')

emails = infile.read().split('----------------------')
for email in emails:
    sender = ''
    receiver = ''
    date = ''
    lines = email.split('\n')
    for line in lines:
        if line.startswith('From: '):
            sender = line.split()[1]
        if line.startswith('To: '):
            receiver = line.split()[1]
        if line.startswith('From '):
            date= line.split()[-1]
    if sender and receiver and date:
        print('To:{}\tFrom:{}\tDate:{}'.format(sender, receiver, date))
# Out:
# To:stephen.marquard@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:louis@media.berkeley.edu	From:source@collab.sakaiproject.org	Date:2008
# To:zqian@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:rjlowe@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:zqian@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:rjlowe@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:cwen@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:cwen@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:gsilver@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:gsilver@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:zqian@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:gsilver@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:wagnermr@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:zqian@umich.edu	From:source@collab.sakaiproject.org	Date:2008
# To:antranig@caret.cam.ac.uk	From:source@collab.sakaiproject.org	Date:2008
# To:gopal.ramasammycook@gmail.com	From:source@collab.sakaiproject.org	Date:2008
# To:david.horwitz@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:david.horwitz@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:david.horwitz@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:david.horwitz@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:stephen.marquard@uct.ac.za	From:source@collab.sakaiproject.org	Date:2008
# To:louis@media.berkeley.edu	From:source@collab.sakaiproject.org	Date:2008
# To:louis@media.berkeley.edu	From:source@collab.sakaiproject.org	Date:2008
# To:ray@media.berkeley.edu	From:source@collab.sakaiproject.org	Date:2008
# To:cwen@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:cwen@iupui.edu	From:source@collab.sakaiproject.org	Date:2008
# To:cwen@iupui.edu	From:source@collab.sakaiproject.org	Date:2008

# %%
x = 'ww'
if x:
    print('+')
# Out:
# +
